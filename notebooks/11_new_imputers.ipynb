# %% [markdown]
# [![Open in Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/justmarkham/scikit-learn-tips/master?filepath=notebooks%2F11_new_imputers.ipynb)
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/justmarkham/scikit-learn-tips/blob/master/notebooks/11_new_imputers.ipynb)
#
# # 🤖⚡ scikit-learn tip #11 ([video](https://www.youtube.com/watch?v=m_qKhnaYZlc&list=PL5-da3qGB5ID7YYAqireYEew2mWVvgmj6&index=11))
#
# Need something better than SimpleImputer for missing value imputation?
#
# Try KNNImputer or IterativeImputer (inspired by R's MICE package). Both are multivariate approaches (they take other features into account!)
#
# See example 👇

# %%
import pandas as pd
df = pd.read_csv('http://bit.ly/kaggletrain', nrows=6)

# %%
cols = ['SibSp', 'Fare', 'Age']
X = df[cols]

# %%
X
# Out:
#    SibSp     Fare   Age
# 0      1   7.2500  22.0
# 1      1  71.2833  38.0
# 2      0   7.9250  26.0
# 3      1  53.1000  35.0
# 4      0   8.0500  35.0
# 5      0   8.4583   NaN

# %%
# new in 0.21, and still "experimental" so it must be enabled explicitly
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
impute_it = IterativeImputer()
impute_it.fit_transform(X)
# Out:
# array([[ 1.        ,  7.25      , 22.        ],
#        [ 1.        , 71.2833    , 38.        ],
#        [ 0.        ,  7.925     , 26.        ],
#        [ 1.        , 53.1       , 35.        ],
#        [ 0.        ,  8.05      , 35.        ],
#        [ 0.        ,  8.4583    , 28.50639495]])

# %%
# new in 0.22
from sklearn.impute import KNNImputer

# %%
impute_knn = KNNImputer(n_neighbors=2)
impute_knn.fit_transform(X)
# Out:
# array([[ 1.    ,  7.25  , 22.    ],
#        [ 1.    , 71.2833, 38.    ],
#        [ 0.    ,  7.925 , 26.    ],
#        [ 1.    , 53.1   , 35.    ],
#        [ 0.    ,  8.05  , 35.    ],
#        [ 0.    ,  8.4583, 30.5   ]])

# %% [markdown]
# ### Want more tips? [View all tips on GitHub](https://github.com/justmarkham/scikit-learn-tips) or [Sign up to receive 2 tips by email every week](https://scikit-learn.tips) 💌
#
# © 2020 [Data School](https://www.dataschool.io). All rights reserved.
